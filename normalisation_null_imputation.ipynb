# %%
import pandas as pd
import numpy as np

# %%
filename = 'laptop_200.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    id   brand        series  weight  ram  price  graphics   disk  battery  \
# 0   0      HP  14s-dy2506TU    1.46  8.0  38990       NaN    NaN      NaN
# 1   1  Lenovo           NaN    1.20  4.0  23890       NaN    NaN      8.0
# 2   2    ASUS           NaN    1.80  4.0  26990       4.0  256.0      6.0
# 3   3      HP           NaN    3.00  NaN  19999       NaN    NaN      2.0
# 4   4  Lenovo           NaN    1.20  4.0  23890       NaN    NaN      8.0
#
#      display  processor  max_memory  \
# 0  14.015748        3.7        16.0
# 1  11.600000        2.8         4.0
# 2  17.795276        2.8         8.0
# 3  15.600000        2.2        16.0
# 4  11.600000        2.8         4.0
#
#                                                  url  \
# 0  https://amazon.in/gp/slredirect/picassoRedirec...
# 1  https://amazon.in/gp/slredirect/picassoRedirec...
# 2  https://amazon.in/ASUS-15-6-inch-Integrated-Tr...
# 3  https://amazon.in/Renewed-HP-650-Generation-Wa...
# 4  https://amazon.in/Lenovo-IdeaPad-Celeron-Plati...
#
#                                            image_url              rating
# 0  https://images-eu.ssl-images-amazon.com/images...  4.2 out of 5 stars
# 1  https://m.media-amazon.com/images/I/41F52ef+pd...  3.8 out of 5 stars
# 2  https://images-eu.ssl-images-amazon.com/images...  4.1 out of 5 stars
# 3  https://m.media-amazon.com/images/I/41+dy19aYE...                 NaN
# 4  https://m.media-amazon.com/images/I/41F52ef+pd...  3.8 out of 5 stars

# %%
def get_null_count(filename):
    df = pd.read_csv(filename)
    return df.isnull().sum()

# %%
get_null_count(filename)
# Out:
# id              0
# brand           0
# series        135
# weight          0
# ram             7
# price           0
# graphics      152
# disk           63
# battery       105
# display        11
# processor       8
# max_memory     12
# url             0
# image_url       0
# rating         15
# dtype: int64

# %%
df.drop(columns= ["id"])

df['id'] = np.arange(len(df))

# %%
df.isnull().sum()
# Out:
# id              0
# brand           0
# series        135
# weight          0
# ram             7
# price           0
# graphics      152
# disk           63
# battery       105
# display        11
# processor       8
# max_memory     12
# url             0
# image_url       0
# rating         15
# dtype: int64

# %%
def preprocess(df):
    df['weight'] = df['weight'].fillna(df['weight'].mean())
    df['ram'] = df['ram'].fillna(df['ram'].median())
    df['price'] = df['price'].fillna(df['price'].mean())
    df['graphics'] = df['graphics'].fillna(0)
    df['disk'] = df['disk'].fillna(df['disk'].median())
    df['battery'] = df['battery'].fillna(df['battery'].median())
    df['display'] = df['display'].fillna(df['display'].median())
    df['processor'] = df['processor'].fillna(df['processor'].median())
    df['max_memory'] = df['max_memory'].fillna(
        df['max_memory'].median())
    df['series'] = df['series'].fillna('')
    df['rating'] = df['rating'].fillna('3.0 out of 5 stars')
    return df

# %%
df = preprocess(df)

# %%
def normalise_min_max(df):
    '''
    df all cols should be numerical 
    note: normalising values between 1 to 2
    '''
    # df = pd.DataFrame()
    for column in df.columns:
        if df[column].dtype == float or  df[column].dtype == int  and column != 'id':
            df[column+"_norm"] = ((df[column] - df[column].min()) /
                                (df[column].max() - df[column].min())+1)
    return df

# %%
df = normalise_min_max(df)

df.head()
# Out:
#    id   brand        series  weight  ram  price  graphics   disk  battery  \
# 0   0      HP  14s-dy2506TU    1.46  8.0  38990       0.0  512.0      6.0
# 1   1  Lenovo                  1.20  4.0  23890       0.0  512.0      8.0
# 2   2    ASUS                  1.80  4.0  26990       4.0  256.0      6.0
# 3   3      HP                  3.00  8.0  19999       0.0  512.0      2.0
# 4   4  Lenovo                  1.20  4.0  23890       0.0  512.0      8.0
#
#      display  ...              rating  weight_norm  ram_norm price_norm  \
# 0  14.015748  ...  4.2 out of 5 stars     1.186312  1.333333   1.128441
# 1  11.600000  ...  3.8 out of 5 stars     1.087452  1.000000   1.044084
# 2  17.795276  ...  4.1 out of 5 stars     1.315589  1.000000   1.061402
# 3  15.600000  ...  3.0 out of 5 stars     1.771863  1.333333   1.022346
# 4  11.600000  ...  3.8 out of 5 stars     1.087452  1.000000   1.044084
#
#   graphics_norm  disk_norm  battery_norm  display_norm  processor_norm  \
# 0         1.000   1.238095          1.36      1.389934        1.722222
# 1         1.000   1.238095          1.52      1.000000        1.472222
# 2         1.125   1.111111          1.36      2.000000        1.472222
# 3         1.000   1.238095          1.04      1.645653        1.305556
# 4         1.000   1.238095          1.52      1.000000        1.472222
#
#    max_memory_norm
# 0         1.200000
# 1         1.000000
# 2         1.066667
# 3         1.200000
# 4         1.000000
#
# [5 rows x 24 columns]
